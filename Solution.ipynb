# %% [markdown]
# # Assignment 3 - NumPy
# This assignment is about slicing and plotting.
#
# ## Obnoxious Consequence
# - Martin Snedvig Rasmussen
# - Michael Ejdal Lundsgaard
# - Morten Bokkenheuser-Bæhr

# %% [markdown]
# ## Create jupyter notebook with 4 data illustrations
#
# 1. First create a file with your python module. This is where you should put your functions to be used in the notebook.
# 2. Second create a function to read the csv file containing Copenhagen city population data and return a numpy array (numpy.ndarray). **hint:** use `np.genfromtxt(filename, delimiter=',', dtype=np.uint, skip_header=1)` as in the slides
# 3. Third create a function that can extract the number of all the citizens from native english speaking countries and from non english speaking countries. How many are there of each? (**hint** remember that with python you can return multiple values from a function).
# 4. Now create another function that can take 2 arguments:
#   - 1: the dataset in the form of a 2dimensional data array where y=data rows and x=[year, area, age nationality, amount].
#   - 2: the mask in the form: data[:,3] == 5120 to find swedish or data[:,0] == 1999 to filter on year
#   - the return value must be the filtered dataset.
# 5. Create another function that can take 2 arguments:
#   - a dataset with same characteristics as above and
#   - a value for the x-axis (either year, area, age or nationality)
#   - return value should be the accumulated population for all x-values.
#   - **hint:** if year is chosen for x then y is all accumulated amounts from all areas, ages and nationalities.
# 6. Create Illustration 1: In your notebook use the above function and create a 2d array of year as x and accumulated amount as y:
#   - create a line graph of the population change over time for all of Copenhagen
# 7. Create illustration 2: In your notebook use your module to create a dataset where development of all German citizens can be shown over time
# 8. Create illustration 3: Show a bar plot of all the 18-25 year old in the different areas of copenhagen and in the same plot show (in a different color) all 60-67 year old in the different areas.
# 9. Create illustration 4: show a pie chart of age groups (0-10, 10-20, 20-30 ...) in Østerbro part of Copenhagen. create another similar piechart for Vesterbro.

# %% [markdown]
# ## Part 02

# %%
import my_module

print(my_module.read_csv_file())
# Out:
# [[2015    1    0 5100  614]
#  [2015    1    0 5104    2]
#  [2015    1    0 5106    1]
#  ...
#  [1992   99   89 5100    1]
#  [1992   99   90 5180    1]
#  [1992   99   93 5100    1]]

# %% [markdown]
# ## Part 03

# %%
import my_module
from data import country_codes, neighb

print("Native English speakers")
print({x:country_codes[x] for x in my_module.native_english_speaking}, "\n")

native_english, non_english = my_module.no_english_non_english()

print("Native English Speaking pr Year(1992-2015)", "\n", native_english, "\n")
print("Non-native English Speaking pr Year(1992-2015)", "\n", non_english, "\n")
# Out:
# Native English speakers
# {5142: 'Irland', 5309: 'Antigua og Barbuda', 5502: 'Australien', 5303: 'Bahamas', 5305: 'Barbados', 5526: 'Belize', 5314: 'Canada', 5326: 'Dominikanske Republik', 5339: 'Grenada', 5308: 'Guyana', 5352: 'Jamaica', 5514: 'New Zealand', 5625: 'Skt. Kitts og Nevis', 5347: 'Skt. Lucia', 5311: 'Skt. Vincent og Grenadinerne', 5374: 'Trinidad og Tobago', 5170: 'Storbritannien', 5390: 'USA'}
#
# Native English Speaking pr Year(1992-2015)
#  [4736 4838 5026 5430 5698 6020 6124 6224 6332 6297 6272 6257 6196 6359
#  6299 6574 7008 7278 7674 8175 8572 8461 9323 9053]
#
# Non-native English Speaking pr Year(1992-2015)
#  [459830 461291 462227 465870 471053 477638 481845 484858 489367 492851
#  494259 495028 495468 496003 494859 497125 502853 511296 520534 531367
#  540478 550979 560849 571242]

# %% [markdown]
# ### Issues
#
# Sometimes it prints sometimes it doesnt... If for some reason you don't see an output check the below link
#
# [Result from Part 03](https://imgur.com/FvNSfVU)

# %% [markdown]
# ## Part 04

# %%
import my_module

dataset = my_module.read_csv_file()

# Deffining the masks
swedish_mask = (dataset[:,3] == 5120)
year_1992_mask = (dataset[:,0] == 1999) 

print("Filter by year", "\n")
print(my_module.filtered_data(dataset, year_1992_mask))
print("-"*30)

print("Filter by swedes", "\n")
print(my_module.filtered_data(dataset, swedish_mask))
print("-"*30)
# Out:
# Filter by year
#
# [[1999    1    0 5100  543]
#  [1999    1    0 5103    1]
#  [1999    1    0 5104    1]
#  ...
#  [1999   99   86 5100    1]
#  [1999   99   94 5100    1]
#  [1999   99  100 5100    1]]
# ------------------------------
# Filter by swedes
#
# [[2015    1    0 5120    4]
#  [2015    1    1 5120    4]
#  [2015    1    2 5120    3]
#  ...
#  [1992   99   53 5120    1]
#  [1992   99   54 5120    1]
#  [1992   99   55 5120    1]]
# ------------------------------

# %% [markdown]
# ## Part 05

# %%
import my_module

data = my_module.read_csv_file()

print("By Year", "\n" + "-"*60)
print(my_module.get_data_by_x(data, 0))

# Masking to only one year
#year_mask = (data[:,0] == 2015)
#year_data = my_module.filtered_data(data, year_mask)

#print("\n","By Area in 2015", "\n" + "-"*60)
#print(my_module.get_data_by_x(data, 1))

#print("\n","By Age in 2015", "\n" + "-"*60)
#print(my_module.get_data_by_x(data, 2))

#print("\n","By Nationality in 2015", "\n" + "-"*60)
#print(my_module.get_data_by_x(data, 3))
# Out:
# By Year
# ------------------------------------------------------------
# [[  1992 464566]
#  [  1993 466129]
#  [  1994 467253]
#  [  1995 471300]
#  [  1996 476751]
#  [  1997 483658]
#  [  1998 487969]
#  [  1999 491082]
#  [  2000 495699]
#  [  2001 499148]
#  [  2002 500531]
#  [  2003 501285]
#  [  2004 501664]
#  [  2005 502362]
#  [  2006 501158]
#  [  2007 503699]
#  [  2008 509861]
#  [  2009 518574]
#  [  2010 528208]
#  [  2011 539542]
#  [  2012 549050]
#  [  2013 559440]
#  [  2014 570172]
#  [  2015 580295]]

# %% [markdown]
# ## Part 06

# %%
import my_module
import matplotlib.pyplot as plt
# %matplotlib notebook

data = my_module.read_csv_file()
year_data = my_module.get_data_by_x(data, 0)

plt.figure()

plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Copenhagen - Population Change Over Time', fontsize=14)

plt.plot(year_data[:,0], year_data[:,1])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Part 07

# %%
import my_module
import matplotlib.pyplot as plt
# %matplotlib notebook

data = my_module.read_csv_file()
german_mask = data[:,3] == 5180

german_data_filtered = my_module.filtered_data(data, german_mask)
german_data = my_module.get_data_by_x(german_data_filtered, 0)

plt.figure()

plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Germans In Copenhagen - Population Change Over Time', fontsize=14)

plt.plot(german_data[:,0], german_data[:,1])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Part 08

# %%
import numpy as np
import my_module
import matplotlib.pyplot as plt
from data import neighb
# %matplotlib notebook

# Reading the CSV file
data = my_module.read_csv_file()

# Defining the mask for the young and elderly (18-25 and 60-67)
year = 2015
young_mask = (data[:,0] == year) & (data[:,2] >= 18) & (data[:,2] <= 25)
elder_mask = (data[:,0] == year) & (data[:,2] >= 60) & (data[:,2] <= 67)

# Using our module to filter the csv file with our mask
young_data_filtered = my_module.filtered_data(data, young_mask)
elder_data_filtered = my_module.filtered_data(data, elder_mask)

# Loop through the prev filtered data, and inserting it into our nighbourhood. 
# Here we're making a dict, where keys = nigbhourhood keys and values is the total amoun in that area.
# We're having n as the neighb.keys
young_by_area = {n:young_data_filtered[young_data_filtered[:,1] == n][:,4].sum() for n in list(set(young_data_filtered[:,1]))}
elder_by_area = {n:elder_data_filtered[elder_data_filtered[:,1] == n][:,4].sum() for n in list(set(elder_data_filtered[:,1]))}

# To show you why we're using a list(set(x)) try and print these two below and spot the difference :) ... 
# Hint: if you dont use list(set(x)) in young_by_area you're going to be here for a long time.
# print(list(set(young_data_filtered[:,1])))
# print(young_data_filtered[:,1])

plt.figure()

# This is to have the two bar plots, be placed side by side, instead of overlapping
# Also to remove that cap between 1,2,3... 10 and 99.
barwidth = 0.4
r1 = np.arange(len(neighb.keys()))
r2 = [x + barwidth for x in r1]

plt.title('Distribution Of Citizens - Aged 18-25 And 60-67 In {}'.format(year), fontsize=12)
plt.xlabel("Area")
plt.ylabel("Amount")

# Here we are defining the xticks
xtick = [x + (barwidth / 2) for x in range(len(neighb.keys()))]
plt.xticks(xtick, neighb.keys())

# You can use this to have the bar plot show names of the area instead of the keys... However it'll crop out the name
#plt.xticks(xtick, neighb.values(), rotation="vertical")

plt.grid()

young_plot = plt.bar(r1, young_by_area.values(), width=barwidth, align='center')
elder_plot = plt.bar(r2, elder_by_area.values(), width=barwidth, align='center', color='red')

plt.legend((young_plot, elder_plot), ('18-25', '60-67'))
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ## Part 09
#
# Create illustration 4: show a pie chart of age groups (0-10, 10-20, 20-30 ...) in Østerbro part of Copenhagen. create another similar piechart for Vesterbro.

# %%
import my_module
import matplotlib.pyplot as plt
from data import neighb
# %matplotlib notebook

# Defnies the variable for the masks - 2 is 'Østerbro' and 4 is 'Vesterbro' - you can do print(neighb)
year = 2015
chart_one = 2
chart_two = 4

# Get data
dd = my_module.read_csv_file()

# Defining the masks
chart_one_mask = (dd[:,0] == year) & (dd[:,1] == chart_one)
chart_two_mask = (dd[:,0] == year) & (dd[:,1] == chart_two)

# Applying the mask with filtered_data
chart_one_data = my_module.filtered_data(dd, chart_one_mask)
chart_two_data = my_module.filtered_data(dd, chart_two_mask)

# Grouping the data by ages (0-10, 10-20 ...) 
# range(start, stop[, step]) - https://www.programiz.com/python-programming/methods/built-in/range 
# If we wanted to make age grouping of 5, we would change the step to 5, instead of 10
chart_one_range = range(min(chart_one_data[:,2]), max(chart_one_data[:,2]), 10)
chart_two_range = range(min(chart_two_data[:,2]), max(chart_two_data[:,2]), 10)

# Making a list of people grouped by age - Again if we wanted to changethe ranging grp we could change the 10 to a 5.
chart_one_grouped = [my_module.filtered_data(chart_one_data, (chart_one_data[:,2] >= x) & (chart_one_data[:,2] < x + 10))[:,4].sum() for x in chart_one_range]
chart_two_grouped = [my_module.filtered_data(chart_two_data, (chart_two_data[:,2] >= x) & (chart_two_data[:,2] < x + 10))[:,4].sum() for x in chart_two_range]

# --------------------------- First Chart (Østerbro)--------------------------- #

# https://pythonspot.com/matplotlib-pie-chart/ 
# https://medium.com/python-pandemonium/data-visualization-in-python-pie-charts-in-matplotlib-c71fb0fe5c56

plt.figure() 
# Could evt. use autopct='%1.1f%% to get # shown on the diagram... However it dosnt look good in this case...
plt.pie(chart_one_grouped, startangle=20, explode=[0.025]*len(chart_one_grouped))
plt.title("Age Groups in {} - {}".format(neighb[chart_one], year))

# Making the legends - the reason we are casting them as str, is that you can only concatenate str (not "int") to str
# The reason we // 10 is that there's 0-104 age but we've only made 11 age groups
# The // opeator: divides and returns the integer value of the quotient. It dumps the digits after the decimal.
chart_lables =  [str(x) + '-' + str(x + 10) + ': '+ str(chart_one_grouped[x // 10]) for x in chart_one_range]
plt.legend(chart_lables, loc='center left', bbox_to_anchor=(1, 0.5))

# Docstring: Set equal scaling (i.e., make circles circular) by changing axis limits.
plt.axis("equal")

# Docstring: Automatically adjust subplot parameters to give specified padding. 
plt.tight_layout()

# --------------------------- Secound Chart (Vesterbro)--------------------------- #

plt.figure() 
plt.pie(chart_two_grouped, startangle=23, explode=[0.025]*len(chart_two_grouped))
plt.title("Age Groups in {} - {}".format(neighb[chart_two], year))

plt.legend(chart_lables, loc='center left', bbox_to_anchor=(1, 0.5))
plt.axis("equal")
plt.tight_layout()

# --------------------------- Fun Data --------------------------- #

msg = "In {} there lives a total of {} people"
print(msg.format(neighb[chart_one], sum(chart_one_grouped)))
print(msg.format(neighb[chart_two], sum(chart_two_grouped)))
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# In Østerbro there lives a total of 75113 people
# In Vesterbro/Kgs. Enghave there lives a total of 61623 people
